# %% [markdown]
# <a href="https://colab.research.google.com/github/vj2268/MSc_FDS_Pracs/blob/main/FDSProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''Scatter plot'''
import pandas as pd
import matplotlib.pyplot as plt
figure, ax = plt.subplots() 
iris = pd.read_csv('Train.csv', names=['ID','Warehouse_block','Mode_of_Shipment','Customer_care_calls','Customer_rating','Cost_of_the_Product','Prior_purchases','Product_importance','Gender','Discount_offered','Weight_in_gms','Reached.on.Time_Y.N'])
print(iris.head())

ax.scatter(iris['Cost_of_the_Product'], iris['Discount_offered'])
ax.set_xlabel('Cost_of_the_Product')
ax.set_ylabel('Discount_offered')
# Out:
#    ID  Warehouse_block  ...  Weight_in_gms  Reached.on.Time_Y.N
# 0  ID  Warehouse_block  ...  Weight_in_gms  Reached.on.Time_Y.N
# 1   1                D  ...           1233                    1
# 2   2                F  ...           3088                    1
# 3   3                A  ...           3374                    1
# 4   4                B  ...           1177                    1
#
# [5 rows x 12 columns]
# Text(0, 0.5, 'Discount_offered')

# %%
'''Line chart'''
import numpy as np

import matplotlib.pyplot as plt

x = range(1, 6)
y = np.random.randint(1, 20, 5)
plt.plot(x,y)
plt.xticks(x)
plt.yticks(y)
# Out:
# ([<matplotlib.axis.YTick at 0x7fbce2006590>,
# ...
#  <a list of 5 Text major ticklabel objects>)

# %%
import matplotlib.pyplot as plt
figure, ax = plt.subplots() 
x=[7,0,2,8,6,8,4,6,0,7,9]
y=[9,6,6,5,6,5,4,5,5,8,1]
ax.plot(x,y)
plt.xticks(x)
plt.yticks(y)
# Out:
# ([<matplotlib.axis.YTick at 0x7fbce5bffa10>,
# ...
#  <a list of 11 Text major ticklabel objects>)

# %%
import pandas as pd
df=pd.DataFrame({
    'name':['Derek','David','Emily','Jennifer','Aaron','Garcia','Spencer'],
    'age':[32,48,30,28,42,26,29],
    'gender':['M','M','F','F','M','F','M'],
    'state':['california','dc','california','dc','dc','texas','california'],
    "num_children":[1,3,0,2,1,0,3],
    'num_pets':[2,0,1,2,0,2,0]
})
ax=plt.gca()
df.plot(x='name',y='num_children',ax=ax)
df.plot(x='name',y='num_pets',ax=ax,color='red')

# %%
columns=iris.columns.drop(['Reached.on.Time_Y.N'])
x_data=range(0,iris.shape[0])
fig,ax=plt.subplots()
for column in columns:
  ax.plot(x_data,iris[column],label=column)
ax.set_title('Iris Dataset')
ax.legend()

# %%
'''HISTOGRAM'''
import matplotlib.pyplot as plt
fig,ax=plt.subplots()
ax.hist(iris['Customer_rating'])
ax.set_title('Train')
ax.set_xlabel('Customer_rating')
ax.set_ylabel('frequency')
# Out:
# Text(0, 0.5, 'frequency')

# %%
import matplotlib.pyplot as plt
fig,ax=plt.subplots()
x=[2,7,8,2,1,4,4,2,1,3,2,9,1,1,2,3]
ax.hist(x)
# Out:
# (array([4., 5., 2., 2., 0., 0., 0., 1., 1., 1.]),
#  array([1. , 1.8, 2.6, 3.4, 4.2, 5. , 5.8, 6.6, 7.4, 8.2, 9. ]),
#  <a list of 10 Patch objects>)

# %%
import pandas as pd
wine_reviews=pd.read_csv('Train.csv',index_col=0)
wine_reviews.head()
# Out:
#    Warehouse_block Mode_of_Shipment  ...  Weight_in_gms  Reached.on.Time_Y.N
# ID                                   ...
# 1                D           Flight  ...           1233                    1
# 2                F           Flight  ...           3088                    1
# 3                A           Flight  ...           3374                    1
# 4                B           Flight  ...           1177                    1
# 5                C           Flight  ...           2484                    1
#
# [5 rows x 11 columns]

# %%
fig,ax=plt.subplots()
data=wine_reviews['Prior_purchases'].value_counts()
points=data.index
frequency=data.values
ax.bar(points,frequency)
ax.set_title('review')
ax.set_xlabel('points')
ax.set_ylabel('frequency')
# Out:
# Text(0, 0.5, 'frequency')

# %%
wine_reviews['Prior_purchases'].value_counts().sort_index().plot.bar()

# %%
import numpy as np
objects=('Car','Train','Motorbike','Bicycle')
y_pos=np.arange(len(objects))
perfomance=[12,15,8,5]
plt.bar(y_pos,perfomance,width=0.5,align='center',alpha=0.5,color=['r','g','b','r'])
plt.xticks(y_pos,objects)
plt.ylabel('Usage')
plt.xlabel('Modes of Transportation')
plt.title('Modes of Transportation usage')
# Out:
# Text(0.5, 1.0, 'Modes of Transportation usage')

# %%
plt.figure(figsize=(14,8))
countries=['USA','Canada','France','Germany','UK','India']
totalDeaths=[92496,37312,7971,27136,40597,9449]
plt.bar(countries,totalDeaths,width=0.9,align='center',color='cyan',edgecolor='red')
i=1.0
j=200
for i in range(len(countries)):
  plt.annotate(totalDeaths[i],(-0.1+i,totalDeaths[i]+j))

plt.legend(labels=['Total deaths'])
plt.title('Bar plot representing the total deaths')
plt.xlabel('countries')
plt.ylabel('deaths')
plt.savefig('barplot.png')

# %%
import pandas as pd
from matplotlib import pyplot as plt
Data={"country":["USA","CANADA","GERMANY","EUROPE","INDIA"],
      "GDP_Per_Capita":[45000,42000,51000,49000,47000],
      "Income_Per_Capita":[4500,5750,8455,7500,5000]}
df= pd.DataFrame(Data)

df.plot(x='country',y=["GDP_Per_Capita",'Income_Per_Capita'],kind='bar')

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=[15,10])

totalDeath=[11355,37312,59710,74735,33645]
totalRecovery=[73480,32562,23688,12995,16658]
activeCases=[9958,7973,2399,1230,3430]
country=["USA","Brazil","Russia","India","Italy"]

X=np.arange(len(totalDeath))

plt.bar(X,totalDeath,color='r',width=0.25)
plt.bar(X+0.25,totalRecovery,color='g',width=0.25)
plt.bar(X+0.5,activeCases,color='b',width=0.25)

plt.legend(['Total Deaths','Total Recovery','Active Cases'])
plt.xticks([i+0.25 for i in range(5)],country)

plt.title("Bar plot representing the total deaths, total recovered cases and active cases country wise")

plt.xlabel('Countries')
plt.ylabel('Cases')
plt.show()

# %%
# Pie Chart
from pandas import DataFrame
import matplotlib.pyplot as plt

Data={'Tasks':[650,500,845],'Task_Type':['Tasks Pending','Task Ongoing','Task Completed']}
df=DataFrame(Data)
df.set_index("Task_Type",inplace=True)

df.plot.pie(y='Tasks',figsize=(8,8),autopct='%1.2f%%',startangle=100)

# %%
import numpy as np
import matplotlib.pyplot as plt



labels=['Civil','Electrical','Mechanical','Chemical']
sizes=[25,55,65,35]

fig,ax=plt.subplots()
ax.pie(sizes,labels=labels,autopct='%1.3f%%')
ax.axis('equal')
ax.set_title('Engineering Disciplines')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt



labels=['Civil','Electrical','Mechanical','Chemical']
sizes=[25,55,65,35]

explode=[0.2,0.2,0.2,0.2]

fig,ax=plt.subplots()
ax.pie(sizes,labels=labels,autopct='%1.2f%%',startangle=90,shadow=True,explode=explode)
ax.axis('equal')
ax.set_title('Engineering Disciplines')
plt.show()

# %%
#Subplots

plt.figure(figsize=(20,10))
plt.subplot(3,2,1)
plt.bar(range(1,6),np.random.randint(1,20,5))
plt.title("3,2,1")

plt.subplot(3,2,2)
plt.bar(range(1,6),np.random.randint(1,20,5))
plt.title("3,2,2")

plt.subplot(3,2,3)
plt.scatter(range(1,6),np.random.randint(1,20,5),s=100,color='r')
plt.title("3,2,3")

plt.subplot(3,2,4)
plt.plot(range(1,6),np.random.randint(1,20,5),marker='o',color='g',linestyle='--')
plt.title("3,2,4")
# Out:
# Text(0.5, 1.0, '3,2,4')

# %%
plt.bar(range(1,6),np.random.randint(1,20,5),width=0.5,color='g')
plt.scatter(range(1,6),np.random.randint(1,20,5),s=200,color='b')
plt.plot(range(1,6),np.random.randint(1,20,5),marker='o',color='r',linestyle='-.')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

cars_data=pd.read_csv('Train.csv',index_col=0,na_values=["??","????"])
cars_data.size
# Out:
# 550

# %%
cars_data.dropna(axis=0,inplace=True)
cars_data.size
# Out:
# 550

# %%
cars_data=pd.read_csv('Train.csv',index_col=0)
cars_data.head()
# Out:
#    Warehouse_block Mode_of_Shipment  ...  Weight_in_gms  Reached.on.Time_Y.N
# ID                                   ...
# 1                D           Flight  ...           1233                    1
# 2                F           Flight  ...           3088                    1
# 3                A           Flight  ...           3374                    1
# 4                B           Flight  ...           1177                    1
# 5                C           Flight  ...           2484                    1
#
# [5 rows x 11 columns]

# %%
sns.set(style='darkgrid')
sns.regplot(x=cars_data['Discount_offered'],y=cars_data['Cost_of_the_Product'])

# %%
sns.regplot(x=cars_data['Discount_offered'],y=cars_data['Cost_of_the_Product'],fit_reg=False)

# %%
sns.regplot(x=cars_data['Discount_offered'],y=cars_data['Cost_of_the_Product'],fit_reg=False,marker='*')

# %%
sns.lmplot(x='Discount_offered',y='Cost_of_the_Product',data=cars_data,fit_reg=False,hue='Prior_purchases',legend=True,palette='Set1')

# %%
sns.distplot(cars_data['Discount_offered'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(cars_data['Discount_offered'],kde=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(cars_data['Discount_offered'],kde=False,bins=5)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.countplot(x='Prior_purchases',data=cars_data)

# %%
sns.countplot(x='Prior_purchases',data=cars_data,hue='Gender')

# %%
sns.boxplot(x=cars_data['Prior_purchases'],y=cars_data['Cost_of_the_Product'])

# %%
sns.pairplot(cars_data,kind='scatter',hue='Prior_purchases',diag_kws={'bw':0.1})
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.1 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.1 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.1 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# ...
